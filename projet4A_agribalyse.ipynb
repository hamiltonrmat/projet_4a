# %% [markdown]
# L'import des librairies utilisées:
#
# - pandas: pour les tableaux
# - numpy: pour les nombres et vecteurs
# - matplotlib et seaborn: pour les graphiques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# fonction "pd.read_csv" : lire les fichiers csv
#
# fonction "pd.read_excel" : lire les fichiers excel

# %%
data = pd.read_csv('/content/Agribalyse_Synthese (2).csv')

# %% [markdown]
# data : nom de la variable ou on a stocké notre table

# %%
data.head()
# Out:
#   Code AGB  Code CIQUAL                        Groupe d'aliment  \
# 0    11084        11084  aides culinaires et ingrédients divers
# 1    11023        11023  aides culinaires et ingrédients divers
# 2    11000        11000  aides culinaires et ingrédients divers
# 3    11093        11093  aides culinaires et ingrédients divers
# 4    20995        20995  aides culinaires et ingrédients divers
#
#   Sous-groupe d'aliment                         Nom du Produit en Français  \
# 0                algues                                  Agar (algue), cru
# 1                herbes                                  Ail séché, poudre
# 2                herbes                                           Ail, cru
# 3                herbes                                       Aneth, frais
# 4                algues  Ao-nori (Enteromorpha sp.), séchée ou déshydratée
#
#                                             LCI Name  code saison  code avion  \
# ...

# %%
data.shape
# Out:
# (2518, 29)

# %% [markdown]
# x.columns affiche les colonnes du dataset x
#
# notre fichier s'appelle data, donc data.columns

# %%
etu_projet_4A = ['Jules', 'Margaux']

# %%
data.columns
# Out:
# Index(['Code AGB', 'Code CIQUAL', 'Groupe d'aliment', 'Sous-groupe d'aliment',
#        'Nom du Produit en Français', 'LCI Name', 'code saison', 'code avion',
#        'Livraison', 'Matériau d'emballage', 'Préparation', 'DQR',
#        'Score unique EF', 'Changement climatique',
#        'Appauvrissement de la couche d'ozone', 'Rayonnements ionisants',
#        'Formation photochimique d'ozone', 'Particules fines',
#        'Effets toxicologiques sur la santé humaine : substances non-cancérogènes',
#        'Effets toxicologiques sur la santé humaine : substances cancérogènes',
#        'Acidification terrestre et eaux douces', 'Eutrophisation eaux douces',
#        'Eutrophisation marine', 'Eutrophisation terrestre',
#        'Écotoxicité pour écosystèmes aquatiques d'eau douce',
#        'Utilisation du sol', 'Épuisement des ressources eau',
#        'Épuisement des ressources énergétiques',
#        'Épuisement des ressources minéraux'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Code AGB', 'Code CIQUAL', 'Groupe d'aliment', 'Sous-groupe d'aliment',
#        'Nom du Produit en Français', 'LCI Name', 'code saison', 'code avion',
#        'Livraison', 'Matériau d'emballage', 'Préparation', 'DQR',
#        'Score unique EF', 'Changement climatique',
#        'Appauvrissement de la couche d'ozone', 'Rayonnements ionisants',
#        'Formation photochimique d'ozone', 'Particules fines',
#        'Effets toxicologiques sur la santé humaine : substances non-cancérogènes',
#        'Effets toxicologiques sur la santé humaine : substances cancérogènes',
#        'Acidification terrestre et eaux douces', 'Eutrophisation eaux douces',
#        'Eutrophisation marine', 'Eutrophisation terrestre',
#        'Écotoxicité pour écosystèmes aquatiques d'eau douce',
#        'Utilisation du sol', 'Épuisement des ressources eau',
#        'Épuisement des ressources énergétiques',
#        'Épuisement des ressources minéraux'],
#       dtype='object')

# %%
cols_importantes = ['Score unique EF', 'Changement climatique',
       "Appauvrissement de la couche d'ozone", 'Rayonnements ionisants',
       "Formation photochimique d'ozone", 'Particules fines',
       'Acidification terrestre et eaux douces', 'Eutrophisation eaux douces',
       'Eutrophisation marine', 'Eutrophisation terrestre',
       "Écotoxicité pour écosystèmes aquatiques d'eau douce",
       'Utilisation du sol', 'Épuisement des ressources eau',
       'Épuisement des ressources énergétiques',
       'Épuisement des ressources minéraux']

# %%
a = 1

# %%
a = 2

# %%
a
# Out:
# 2

# %%
df = df.drop(['Code AGB', 'Code CIQUAL', "Groupe d'aliment", "Sous-groupe d'aliment",
       'Nom du Produit en Français', 'LCI Name', 'code saison', 'code avion',
       'Livraison', "Matériau d'emballage", 'Préparation', 'DQR'], axis=1)

# %%
df[cols_importantes]
# Out:
#       Score unique EF  Changement climatique  \
# 0            1.226025               6.745806
# 4            1.226025               6.745806
# 5            1.199491               6.560744
# 6            0.217581               1.960504
# 10           0.220080               1.126604
# ...               ...                    ...
# 2511         2.774882              28.981364
# 2512         2.149621              22.366989
# 2513         2.149621              22.366989
# 2514         2.231243              23.466474
# 2517         0.843744               5.910328
#
#       Appauvrissement de la couche d'ozone  Rayonnements ionisants  \
# 0                             1.017147e-06               11.050022
# 4                             1.017147e-06               11.050022
# 5                             9.803637e-07               11.037991
# 6                             1.037794e-07                0.729160
# 10                            9.059855e-08                0.169409
# ...

# %% [markdown]
# les colonnes dans une table

# %%
pd.DataFrame(data.columns)
# Out:
#                                                     0
# 0                                            Code AGB
# 1                                         Code CIQUAL
# 2                                    Groupe d'aliment
# 3                               Sous-groupe d'aliment
# 4                          Nom du Produit en Français
# 5                                            LCI Name
# 6                                         code saison
# 7                                          code avion
# 8                                           Livraison
# 9                                Matériau d'emballage
# 10                                        Préparation
# 11                                                DQR
# 12                                    Score unique EF
# 13                              Changement climatique
# 14               Appauvrissement de la couche d'ozone
# 15                             Rayonnements ionisants
# ...

# %% [markdown]
# description statistique de chaque variable numérique: "x.describe()"
#
# on peut voir le min, max, moyenne, écart type de chaque variable

# %%
data.shape
# Out:
# (2518, 29)

# %%
df = data[data['DQR'] < 3]

# %%
print('projet 4A')
# Out:
# projet 4A

# %%
df.shape
# Out:
# (1744, 29)

# %%
a = np.round(df.shape[0] / data.shape[0], 3)*100
print(a,'% des lignes du lot de données originales ont un score qualité < 3')
# Out:
# 69.3 % des lignes du lot de données originales ont un score qualité < 3

# %%
df
# Out:
#       Score unique EF  Changement climatique  \
# 0            1.226025               6.745806
# 4            1.226025               6.745806
# 5            1.199491               6.560744
# 6            0.217581               1.960504
# 10           0.220080               1.126604
# ...               ...                    ...
# 2511         2.774882              28.981364
# 2512         2.149621              22.366989
# 2513         2.149621              22.366989
# 2514         2.231243              23.466474
# 2517         0.843744               5.910328
#
#       Appauvrissement de la couche d'ozone  Rayonnements ionisants  \
# 0                             1.017147e-06               11.050022
# 4                             1.017147e-06               11.050022
# 5                             9.803637e-07               11.037991
# 6                             1.037794e-07                0.729160
# 10                            9.059855e-08                0.169409
# ...

# %%
data.describe()
# Out:
#         Code CIQUAL  code saison   code avion          DQR  Score unique EF  \
# count   2518.000000  2518.000000  2518.000000  2518.000000      2518.000000
# mean   22120.156076     1.997617     0.000794     2.768168         0.674660
# std    13832.871850     0.062987     0.028177     0.553070         0.856597
# min        1.000000     0.000000     0.000000     1.200000         0.012941
# 25%    12726.750000     2.000000     0.000000     2.380000         0.157586
# 50%    20499.000000     2.000000     0.000000     2.680000         0.349165
# 75%    26089.500000     2.000000     0.000000     3.090000         0.862760
# max    96778.000000     2.000000     1.000000     4.870000         5.813351
#
#        Changement climatique  Appauvrissement de la couche d'ozone  \
# count            2518.000000                          2.518000e+03
# mean                5.352347                          5.295133e-07
# std                 7.605873                          4.873864e-06
# ...

# %%
sns.boxplot(data['Score unique EF'])
# Out:
# <Axes: ylabel='Score unique EF'>

# %%
data['Score unique EF']
# Out:
# 0       1.226025
# 1       0.103513
# 2       0.064652
# 3       0.131581
# 4       1.226025
#           ...
# 2513    2.149621
# 2514    2.231243
# 2515    0.810828
# 2516    1.018584
# 2517    0.843744
# Name: Score unique EF, Length: 2518, dtype: float64

# %%
plt.plot()

# %%
plt.plot(data['Score unique EF'])

# huqfkdhkjfhsdjkfhjskclfkdlfdk

# %%
# sert a changer la taille de l'image
plt.figure(figsize=(15,5))
# la ligne la plus importante: plt.plot(x)
# x pour nous : la colonne que l'on veut
# on peut écrire de 2 façons: plt.plot(data.DQR) ou plt.plot(data['DQR']) pour afficher le graphique de la variable 'DQR'
plt.plot(data.DQR)
plt.show()

# %%
##afficher la moyenne de la variable 'DQR'
data['DQR'].mean()
# Out:
# 2.768167560570821

# %%
# le meme graphique qu'avant avec la moyenne
plt.figure(figsize=(15,5))
plt.axhline(y=data['DQR'].mean(), color='red', linestyle = '--')
plt.axhline(y=3, color='red', linestyle = '--')
plt.plot(data.DQR)
plt.show()

# %%
data.columns
# Out:
# Index(['Code AGB', 'Code CIQUAL', 'Groupe d'aliment', 'Sous-groupe d'aliment',
#        'Nom du Produit en Français', 'LCI Name', 'code saison', 'code avion',
#        'Livraison', 'Matériau d'emballage', 'Préparation', 'DQR',
#        'Score unique EF', 'Changement climatique',
#        'Appauvrissement de la couche d'ozone', 'Rayonnements ionisants',
#        'Formation photochimique d'ozone', 'Particules fines',
#        'Effets toxicologiques sur la santé humaine : substances non-cancérogènes',
#        'Effets toxicologiques sur la santé humaine : substances cancérogènes',
#        'Acidification terrestre et eaux douces', 'Eutrophisation eaux douces',
#        'Eutrophisation marine', 'Eutrophisation terrestre',
#        'Écotoxicité pour écosystèmes aquatiques d'eau douce',
#        'Utilisation du sol', 'Épuisement des ressources eau',
#        'Épuisement des ressources énergétiques',
#        'Épuisement des ressources minéraux'],
#       dtype='object')

# %%
cols = list(data.columns)

# %%
cols = ['Score unique EF',
 'Changement climatique',
 "Appauvrissement de la couche d'ozone",
 'Rayonnements ionisants',
 "Formation photochimique d'ozone",
 'Particules fines',
 "Effets toxicologiques sur la santé humaine\xa0: substances non-cancérogènes",
 "Effets toxicologiques sur la santé humaine\xa0: substances cancérogènes",
 'Acidification terrestre et eaux douces',
 'Eutrophisation eaux douces',
 'Eutrophisation marine',
 'Eutrophisation terrestre',
 "Écotoxicité pour écosystèmes aquatiques d'eau douce",
 'Utilisation du sol',
 'Épuisement des ressources eau',
 'Épuisement des ressources énergétiques',
 'Épuisement des ressources minéraux']

# %%
df.corr()
# Out:
#                                                     Score unique EF  \
# Score unique EF                                            1.000000
# Changement climatique                                      0.967901
# Appauvrissement de la couche d'ozone                       0.036181
# Rayonnements ionisants                                     0.371135
# Formation photochimique d'ozone                            0.703123
# Particules fines                                           0.977161
# Effets toxicologiques sur la santé humaine : su...         0.919554
# Effets toxicologiques sur la santé humaine : su...         0.944376
# Acidification terrestre et eaux douces                     0.975760
# Eutrophisation eaux douces                                 0.647858
# Eutrophisation marine                                      0.896514
# Eutrophisation terrestre                                   0.964427
# Écotoxicité pour écosystèmes aquatiques d'eau d...         0.796207
# ...

# %%
df = data[cols]
corr = df.corr()
corr
# Out:
#                                                     Score unique EF  \
# Score unique EF                                            1.000000
# Changement climatique                                      0.967901
# Appauvrissement de la couche d'ozone                       0.036181
# Rayonnements ionisants                                     0.371135
# Formation photochimique d'ozone                            0.703123
# Particules fines                                           0.977161
# Effets toxicologiques sur la santé humaine : su...         0.919554
# Effets toxicologiques sur la santé humaine : su...         0.944376
# Acidification terrestre et eaux douces                     0.975760
# Eutrophisation eaux douces                                 0.647858
# Eutrophisation marine                                      0.896514
# Eutrophisation terrestre                                   0.964427
# Écotoxicité pour écosystèmes aquatiques d'eau d...         0.796207
# ...

# %%
corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(10, 7))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, annot=True, vmin=-1, vmax=1)
plt.show()

# %%
df.corr()['Score unique EF'].sort_values(ascending=False)
# Out:
# Score unique EF                                                             1.000000
# Particules fines                                                            0.949450
# Acidification terrestre et eaux douces                                      0.948837
# Changement climatique                                                       0.942614
# Eutrophisation terrestre                                                    0.935761
# Effets toxicologiques sur la santé humaine : substances cancérogènes        0.840435
# Utilisation du sol                                                          0.824579
# Effets toxicologiques sur la santé humaine : substances non-cancérogènes    0.774847
# Eutrophisation marine                                                       0.687258
# Écotoxicité pour écosystèmes aquatiques d'eau douce                         0.664417
# Épuisement des ressources énergétiques                                      0.651793
# ...

# %%
plt.figure(figsize=(15,5))
plt.plot(data['Score unique EF'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.histplot(data['Score unique EF'], kde='True')
plt.axvline(x=data['Score unique EF'].mean(), color='orange')
plt.show()

# %% [markdown]
# # section 1

# %%
data["Groupe d'aliment"].value_counts()
# Out:
# Groupe d'aliment
# viandes, œufs, poissons                        645
# fruits, légumes, légumineuses et oléagineux    426
# produits céréaliers                            376
# entrées et plats composés                      292
# boissons                                       229
# lait et produits laitiers                      223
# aides culinaires et ingrédients divers         160
# matières grasses                                56
# produits sucrés                                 53
# aliments infantiles                             33
# glaces et sorbets                               25
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.catplot(data=data, x="Groupe d'aliment", y="Particules fines", kind="box",height=7,aspect=2)
plt.xticks(rotation=90)
plt.show()

# %%
data[data["Groupe d'aliment"] == 'fruits, légumes, légumineuses et oléagineux']
# Out:
#      Code AGB  Code CIQUAL                             Groupe d'aliment  \
# 714     13712        13712  fruits, légumes, légumineuses et oléagineux
# 715     13713        13713  fruits, légumes, légumineuses et oléagineux
# 716     13714        13714  fruits, légumes, légumineuses et oléagineux
# 717     13715        13715  fruits, légumes, légumineuses et oléagineux
# 718     13000        13000  fruits, légumes, légumineuses et oléagineux
# ...       ...          ...                                          ...
# 1135    20256        20256  fruits, légumes, légumineuses et oléagineux
# 1136    20196        20196  fruits, légumes, légumineuses et oléagineux
# 1137    20050        20050  fruits, légumes, légumineuses et oléagineux
# 1138    15011        15011  fruits, légumes, légumineuses et oléagineux
# 1139    15045        15045  fruits, légumes, légumineuses et oléagineux
#
#                        Sous-groupe d'aliment  \
# 714                                   fruits
# ...

# %%
for x in cols:
  print(x)
  plt.figure(figsize=(12,6))
  sns.histplot(df, x=x, kde=True)
  plt.show()
# Out:
# Score unique EF
# Changement climatique
# Appauvrissement de la couche d'ozone
# Rayonnements ionisants
# Formation photochimique d'ozone
# Particules fines
# Effets toxicologiques sur la santé humaine : substances non-cancérogènes
# Effets toxicologiques sur la santé humaine : substances cancérogènes
# Acidification terrestre et eaux douces
# Eutrophisation eaux douces
# Eutrophisation marine
# Eutrophisation terrestre
# Écotoxicité pour écosystèmes aquatiques d'eau douce
# Utilisation du sol
# Épuisement des ressources eau
# Épuisement des ressources énergétiques
# Épuisement des ressources minéraux

# %%
data
# Out:
#      Code AGB  Code CIQUAL                        Groupe d'aliment  \
# 0       11084        11084  aides culinaires et ingrédients divers
# 1       11023        11023  aides culinaires et ingrédients divers
# 2       11000        11000  aides culinaires et ingrédients divers
# 3       11093        11093  aides culinaires et ingrédients divers
# 4       20995        20995  aides culinaires et ingrédients divers
# ...       ...          ...                                     ...
# 2513     6535         6535                 viandes, œufs, poissons
# 2514     6582         6582                 viandes, œufs, poissons
# 2515    26146        26146                 viandes, œufs, poissons
# 2516    26147        26147                 viandes, œufs, poissons
# 2517    25512        25512                 viandes, œufs, poissons
#
#                  Sous-groupe d'aliment  \
# 0                               algues
# 1                               herbes
# 2                               herbes
# ...

# %%
data[data['Score unique EF']<1.5]
# Out:
#      Code AGB  Code CIQUAL                        Groupe d'aliment  \
# 0       11084        11084  aides culinaires et ingrédients divers
# 1       11023        11023  aides culinaires et ingrédients divers
# 2       11000        11000  aides culinaires et ingrédients divers
# 3       11093        11093  aides culinaires et ingrédients divers
# 4       20995        20995  aides culinaires et ingrédients divers
# ...       ...          ...                                     ...
# 2496     6560         6560                 viandes, œufs, poissons
# 2509     6540         6540                 viandes, œufs, poissons
# 2515    26146        26146                 viandes, œufs, poissons
# 2516    26147        26147                 viandes, œufs, poissons
# 2517    25512        25512                 viandes, œufs, poissons
#
#                  Sous-groupe d'aliment  \
# 0                               algues
# 1                               herbes
# 2                               herbes
# ...
